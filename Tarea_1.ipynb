# %% [markdown]
# #Intento de hacer la tarea jaja

# %% [markdown]
# Ruta del archivo = '/content/drive/MyDrive/Universidad/Semestre/2022-1/Computación estadistica/commerce_data.csv'

# %% [markdown]
# **Insertar imagen del data de Kaggle**
# ##Enlace original para descargar la data https://www.kaggle.com/nowingkim/ecommerce-data-cosmetics-shop

# %% [markdown]
# ![Kaggle ecomerce](![data set e comerce kaggle.JPG](data:image/jpeg;base64,...))
#
#
# ![Kaggle 2](https://miro.medium.com/max/1024/1*bQYZ7fp_wcjWFwpBbcRS-Q.png)

# %% [markdown]
# #Matriz 4x4
# \begin{bmatrix}
# 0 &  4&  -2& 3&\\
# -6 &  2&  10& 9&\\
# 5 & 8 &  5& 16&\\
# 0 &  -2&  9& 7&
# \end{bmatrix}

# %% [markdown]
#  # Punto 4
#  **$$\int_{0}^{8} x^{2}(\tfrac{x+1}{6x^{2}})$$**
